# %%
import json
import numpy as np
import pandas as pd
import pickle
import requests

# %%
with open('./data/player_shots.pickle', 'rb') as f:
    players_shots = pickle.load(f)
with open('./data/player_shots_subset.pickle', 'rb') as f:
    players_shots_subset = pickle.load(f)
with open('./data/players_shots_clean.pickle', 'rb') as f:
    players_shots_clean = pickle.load(f)
with open('./data/player_position.pickle', 'rb') as f:
    players_position = pickle.load(f)

# %%
players_position[players_position['PLAYER_NAME'] == 'Chris Paul']
# Out:
#      PLAYER_ID PLAYER_NAME POSITION POSITION_
# 388     101108  Chris Paul    Guard     Guard
