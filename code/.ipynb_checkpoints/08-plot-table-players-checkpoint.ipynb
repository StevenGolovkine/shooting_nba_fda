# %%
# Load packages
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pickle
import scipy.stats

# %%
with open('./data/players_shots_clean.pickle', 'rb') as f:
    players_shots = pickle.load(f)
with open('./data/player_position.pickle', 'rb') as f:
    players_position = pickle.load(f)

# %%
players_sub = [pp in players_shots['PLAYER_ID'].unique() for pp in players_position['PLAYER_ID']]

# %%
players_position[players_sub]['POSITION_'].value_counts()
# Out:
# POSITION_
# Guard             68
# Forward           43
# Forward-Center    25
# Forward-Guard     24
# Center            13
# Name: count, dtype: int64
